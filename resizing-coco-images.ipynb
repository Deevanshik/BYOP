# %% [markdown]
# ### Import the coco dataset and the annotation file before running the notebook

# %%
# !git clone https://github.com/Deevanshik/COCO-dataset-resize.git
# Out:
# Cloning into 'COCO-dataset-resize'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 35 (delta 17), reused 19 (delta 9), pack-reused 0 (from 0)
# Unpacking objects: 100% (35/35), 21.90 KiB | 1.46 MiB/s, done.

# %%
# !pip install -r /kaggle/working/COCO-dataset-resize/requirements.txt

# %%
import os
custom_dir = "/kaggle/working/COCO-dataset-resize/resized-COCO"
os.makedirs(custom_dir, exist_ok=True)

# %%
# %cd /kaggle/working/COCO-dataset-resize
! sh main.sh
# Out:
# /kaggle/working/COCO-dataset-resize
# Loading annotations file...
# Annotations file loaded.
# Building dictionnaries...
# Dictionnaries built.
# Processing image file 000000391895.jpg and its bounding boxes...
# Reading image /kaggle/input/coco-2017-dataset/coco2017/train2017/000000391895.jpg ...
# Writing resized image /kaggle/working/COCO-dataset-resize/resized-COCO/000000391895.jpg ...
# Resized image /kaggle/working/COCO-dataset-resize/resized-COCO/000000391895.jpg written successfully.
# Processing image file 000000522418.jpg and its bounding boxes...
# Reading image /kaggle/input/coco-2017-dataset/coco2017/train2017/000000522418.jpg ...
# Writing resized image /kaggle/working/COCO-dataset-resize/resized-COCO/000000522418.jpg ...
# Resized image /kaggle/working/COCO-dataset-resize/resized-COCO/000000522418.jpg written successfully.
# Processing image file 000000184613.jpg and its bounding boxes...
# ...

# %%
import shutil

# Path to the folder
folder_path = '/kaggle/working/COCO-dataset-resize/resized-COCO/'

# Path to save the ZIP file
zip_file_path = '/kaggle/working/resized_images.zip'

# Create a zip file of the folder
shutil.make_archive(zip_file_path.replace('.zip', ''), 'zip', folder_path)

print(f"ZIP file created at: {zip_file_path}")
